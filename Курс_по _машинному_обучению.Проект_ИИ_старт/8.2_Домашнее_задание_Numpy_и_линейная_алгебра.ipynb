# %% [markdown]
# # 8.2 Домашнее задание. Numpy и линейная алгебра

# %% [markdown]
# ## Домашнее задание. Numpy и линейная алгебра
# В этом домашнем задании вам предстоит самостоятельно реализовать линейно-алгебраические операции с помощью чистого Python, а затем попрактиковаться в использовании уже готовых реализаций из numpy.
#
# Версия домашнего задания есть на Colab. Мы рекомендуем сначала решать задачи там, а потом уже сдавать в тестирующую систему.
# https://colab.research.google.com/drive/1tgCY8vfbC0oHOe3MSdi6F1dq79SuSml2?usp=share_link

# %%
import numpy as np
import random
import scipy.stats as sps

# %% [markdown]
# # ЗАДАНИЕ

# %% [markdown]
# ##### Вам подаются на вход два вектора a и b в трехмерном пространстве. Реализуйте их скалярное произведение с помощью numpy и без.

# %%
a = np.random.sample((1, 3))
a = list(a)[0]
b = np.random.sample((1, 3))
b = list(b)[0]
print(a, b)
# Out:
# [0.98255734 0.953753   0.99949621] [0.02997759 0.56743026 0.46408045]

# %%
import numpy as np

def no_numpy_scalar(v1, v2):
    #param v1, v2: lists of 3 ints
    #YOUR CODE: please do not use numpy
    
    result = 0
    for i in range(len(v1)):
        result += v1[i]*v2[i]
    return result

def numpy_scalar (v1, v2):
    #param v1, v2: np.arrays[3]
    #YOUR CODE

    result = np.dot(v1,v2)
    return result

# %%
print(no_numpy_scalar(a, b))
# Out:
# 1.0344896621448956

# %%
print(numpy_scalar(a, b))
# Out:
# 1.0344896621448956

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def no_numpy_scalar(v1, v2):
    #param v1, v2: lists of 3 ints
    #YOUR CODE: please do not use numpy

    result = sum([x*y for x,y in zip(v1,v2)]) 
    return result

def numpy_scalar (v1, v2):
    #param v1, v2: np.arrays[3]
    #YOUR CODE

    result = v1 @ v2
    return result

# %%
import numpy as np

def no_numpy_scalar(v1, v2):
    return sum(v1[i]*v2[i] for i in range(len(v1)))

def numpy_scalar (v1, v2):
    return v1 @ v2

# %% [markdown]
# # задача

# %% [markdown]
# ###### Напишите две функции, каждая из которых перемножает две квадратные матрицы: одна без использования встроенных функций numpy, а другая --- с помощью numpy. На вход первой задаче подаются списки размера size по size элементов в каждом. На вход второй задаче подаются объекты типа np.ndarray --- квадратные матрицы одинакового размера.
#
# Первая функция должна возвращать список списков, а вторая -- np.array.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов 
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j),  
# здесь i -- число строк, j -- число столбцов.
a = np.random.sample((100, 100))
b = np.random.sample((100, 100))

# Выведите размерность (ранг) каждой матрицы с помощью функции ndim.
# Используйте функцию shape, что она вывела?

# ========
# Ваш код здесь
# ========
print(a)
print(b)
# Out:
# [[0.77940584 0.56281893 0.95265205 ... 0.71853876 0.01809579 0.10346677]
#  [0.54761348 0.43059574 0.8842863  ... 0.83385621 0.62725927 0.09510622]
#  [0.37900677 0.92473698 0.99743645 ... 0.85640995 0.79683924 0.17544488]
#  ...
#  [0.08392944 0.5181386  0.013571   ... 0.22445917 0.45966487 0.99840174]
#  [0.97374094 0.96853353 0.19908876 ... 0.79426805 0.63549397 0.86022048]
#  [0.17389936 0.48179683 0.58390937 ... 0.71142337 0.96327364 0.38494137]]
# [[0.03887357 0.78601762 0.59143238 ... 0.82398236 0.72056875 0.51223568]
#  [0.18826462 0.79778855 0.047401   ... 0.94921313 0.8204448  0.54683117]
#  [0.01489627 0.51519995 0.23799115 ... 0.24862157 0.32381751 0.46219647]
#  ...
#  [0.53903945 0.60500285 0.99458055 ... 0.68114396 0.87910532 0.04913823]
#  [0.52090009 0.81487756 0.9637739  ... 0.44993292 0.97269014 0.10446984]
#  [0.77979858 0.50290274 0.12065298 ... 0.78146006 0.30895441 0.40954391]]

# %%
q = np.random.sample((3,3))
z = np.random.sample((3,3))

# %%
print(q)
print(z)
# Out:
# [[0.80034328 0.58680165 0.43395523]
#  [0.85962802 0.69738586 0.88446214]
#  [0.99393349 0.05230324 0.69988186]]
# [[0.71153258 0.72753059 0.2039802 ]
#  [0.1177186  0.69603331 0.59268097]
#  [0.33751402 0.53955005 0.98328961]]

# %%
import numpy as np

def no_numpy_mult(first, second):
    """
    param first: list of "size" lists, each contains "size" floats
    param second: list of "size" lists, each contains "size" floats
    """
    result = []
    for i in range(len(first)):
        s = []
        for j in range(len(first)):
            count = 0
            for z in range(len(first)):
                count += first[i][z] * second[z][j]
            s.append(count)
        result.append(s)
        
    
    
    return result

def numpy_mult(first, second):
    """
    param first: np.array[size, size]
    param second: np.array[size, size]
    """

    #YOUR CODE: please use numpy

    result = first @ second
    return result

# %%
print(numpy_mult(q,z))
# Out:
# [[0.78501376 1.22484828 0.93774402]
#  [0.992267   1.58802106 1.45835685]
#  [0.94959306 1.1371431  0.92192845]]

# %%
print(no_numpy_mult(q,z))
# Out:
# [[0.7850137591446779, 1.22484827980447, 0.9377440190984335], [0.9922670009804844, 1.5880210641985624, 1.4583568544678789], [0.949593055195782, 1.1371431043918636, 0.9219284460134626]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def no_numpy_mult(a, b):
    return [[sum(a[i][k]*b[k][j] for k in range(len(a))) for j in range(len(a))] for i in range(len(a))]

def numpy_mult(first, second):
    return first @ second

# %%
import numpy as np

def no_numpy_mult(first, second):
    size = len(first) 
    result = [[0 for i in range(size)] for i in range(size)]
    for i in range(size):
        for j in range(size):
            for k in range(size):
                result[i][j] += first[i][k] * second[k][j]
    return result

def numpy_mult(first, second):
    return first @ second

# %% [markdown]
# # ЗАДАНИЕ

# %% [markdown]
# #### Постановка задачи линейной регрессии, о которой мы будем говорить в следующих модулях, выглядит так.
#
# Дано: матрица XX размера \ell \times nℓ×n и вектор yy размерности \ellℓ.
#
# Необходимо: подобрать вектор ww размерности nn, для которого выражение ||𝑋𝑤−𝑦||^2_2∣∣Xw−y∣∣
# 2
# 2
# ​
#   будет минимально возможным, где ||𝑎||^2_2∣∣a∣∣
# 2
# 2
# ​
#   --- квадрат нормы вектора aa, то есть сумма квадратов компонент вектора aa.
#
# Даны матрица XX и векторы w, yw,y. Напишите функцию, которая находит значение выражения ||𝑋𝑤−𝑦||^2_ 2∣∣Xw−y∣∣
# 2
# 2
# ​
#  . Используйте библиотеку numpy и ее встроенные функции. Предлагаем вам загуглить, как вычислять норму вектора с помощью numpy. Следите за правильными размерностями при применении линейно-алгебраических операций!
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Да, от того, что всё тут так "объясняется" можно несколько устать. Я уже даже не знаю, что хуже - лекции или формулировка заданий...
#
# Нужно вычислить норму от выражения (Xw - y) при помощи встроенной в numpy функции вычисления нормы, а затем возвести её в квадрат. Перемножение матрицы X и вектора w делать через dot или @. Плюс есть момент с тем, что координат в векторе y больше, чем в строке матрицы, т.е. перед тем, как из матрицы вычитать вектор y, нужно транспонировать либо её либо вектор.

# %%
# test
X = np.array([1,2,3,4,5,6]).reshape(3, 2)
w = np.array([0.5, -1.2])
y = np.array([2, -1, 0])

# %%
import numpy as np

def calculate_loss_function(X, w, y):
    

    return np.linalg.norm(X @ w - y)**2

# %%
print(calculate_loss_function(X, w, y))
# Out:
# [-3.9 -2.3 -4.7]

# %%
 X @ w
# Out:
# array([-1.9, -3.3, -4.7])

# %%
np.linalg.norm(X @ w - y)**2
# Out:
# 42.589999999999996

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def calculate_loss_function(X, w, y):
    #YOUR CODE
    a = X @ w - y
    return a.T @ a

# %%
import numpy as np

def calculate_loss_function(X, w, y):
    result = np.sum((np.dot(X, w)-y)**2)
    return result

# %% [markdown]
# # ЗАДАЧА
#
# ![image.png](attachment:image.png)

# %%
X = np.array([1,2,3,4,5,6]).reshape(3, 2)
y = np.array([2, -1, 0])

# %%
print(X)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(y)
# Out:
# [ 2 -1  0]

# %%
import numpy as np

def solve_linear_regression(X, y):

    w_opt = np.linalg.inv(X.T @ X) @ X.T @ y

    return w_opt

# %%
(X.T @ X)
# Out:
# array([[35, 44],
#        [44, 56]])

# %%
np.linalg.inv(X.T @ X)
# Out:
# array([[ 2.33333333, -1.83333333],
#        [-1.83333333,  1.45833333]])

# %%
np.linalg.inv(X.T @ X) @ X.T
# Out:
# array([[-1.33333333, -0.33333333,  0.66666667],
#        [ 1.08333333,  0.33333333, -0.41666667]])

# %%
np.linalg.inv(X.T @ X) @ X.T @ y
# Out:
# array([-2.33333333,  1.83333333])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from numpy.linalg import inv

def solve_linear_regression(X, y):
    w_opt = np.dot(np.dot(inv(np.dot(X.T, X)), X.T), y)

    return w_opt
