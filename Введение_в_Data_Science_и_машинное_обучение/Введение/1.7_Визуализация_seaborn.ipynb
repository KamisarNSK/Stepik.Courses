# %% [markdown]
# # 1.7 Визуализация, seaborn

# %% [markdown]
# ## В этом уроке мы рассмотрим крайне важную часть анализа данных - визуализацию
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Полезные ссылки:
#
# matplotlib https://matplotlib.org/
#
# встроенная в pandas визуализация  https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html
#
# seaborn  https://seaborn.pydata.org/

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
patch_to_file = '/mnt/HC_Volume_18315164/home-jupyter/jupyter-s-kamsarin/Введение_в_Data_Science_и_машинное_обучение/Введение/StudentsPerformance.csv'
sp = pd.read_csv(patch_to_file)

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sp = sp.rename(columns=
              {'parental level of education': 'parental_level_of_education',
               'test preparation course': 'test_preparation_course',
               'math score': 'math_score',
               'reading score': 'reading_score',
               'writing score': 'writing_score'})

# %%
sp.math_score.hist()

# %%
sp.plot.scatter(x='math_score', y='reading_score')

# %%
sns.lmplot(x='math_score', y='reading_score', data = sp)

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data = sp)

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data = sp, fit_reg=False)

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data = sp, fit_reg=False)
ax.set_xlabels('оценка по математике')
ax.set_ylabels('оценка по чтению')

# %% [markdown]
# # задание

# %% [markdown]
# ### Представьте, что у вас есть датафрэйм df, хранящий данные о зарплате за месяц, со всего 1-ой колонкой income.
# https://stepik.org/media/attachments/course/4852/income.csv
# Укажите верные способы, как отрисовать простой график зависимости зарплаты от даты (то, как отображается дата сейчас не важно, главное сам график)
#
# Убедитесь, что вы используте версию seaborn > = 0.9.

# %%
df = pd.read_csv('income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot()

df.plot(kind='line')

df.income.plot()

plt.plot(df.index, df.income)

df['income'].plot()

sns.lineplot(x=df.index, y=df.income)

sns.lineplot(data=df)

# %%
df.plot()

# %%
df.plot(kind='line')

# %%
df.income.plot()

# %%
plt.plot(df.index, df.income)

# %%
df['income'].plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
sns.lineplot(data=df)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # вопрос

# %% [markdown]
# ##### Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных (одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.
#
# В ответе вы должны указать число кластеров в виде числа (например: 3).
#
# У вас есть неограниченное число попыток.
# Время одной попытки: 5 mins

# %%
df=pd.read_csv('dataset_209770_6 (1).txt', sep=' ')

# %%
df.head()
# Out:
#             x           y
# 0  592.898262  900.693543
# 1  900.460559  988.278582
# 2  698.079395  104.201780
# 3  703.820560  113.747004
# 4  701.908327   98.987938

# %%
ax = sns.lmplot(x='x', y='y',data = df, fit_reg=False)

# %%
df.plot()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1=pd.read_csv('dataset_209770_6 (1).txt', sep=' ',header=None)

# %%
df1.head()
# Out:
#                    0                   1
# 0                  x                   y
# 1  592.8982619210801    900.693543037143
# 2  900.4605587401063   988.2785820176333
# 3  698.0793952331607  104.20177981884895
# 4  703.8205600347543  113.74700350818321

# %%
# df = pd.read_csv('path_to_dataset', sep=' ', header=None)
sns.scatterplot(df1.iloc[:, 0], df1.iloc[:, 1], data=df1)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # вопрос

# %% [markdown]
# ###### Скачайте данные, представляющие геномные расстояния между видами, и постройте тепловую карту, чтобы различия было видно наглядно. В ответ впишите, какая картинка соответствует скачанным данным.
#
# https://stepik.org/media/attachments/course/4852/genome_matrix.csv
#
# Чтобы график отображался как на картинках, добавьте
#
# g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
#
# g.xaxis.set_ticks_position('top')
#
# g.xaxis.set_tick_params(rotation=90)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
genome_matrix = pd.read_csv('genome_matrix.csv')
genome_matrix
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
genome_matrix.drop('Unnamed: 0', axis=1)
# Out:
#    species0  species1  species2  species3  species4
# 0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
genome_matrix.set_index('Unnamed: 0')
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(genome_matrix.set_index('Unnamed: 0'))

# %%
sns.heatmap(genome_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-d07e2997adba> in <module>
# ----> 1 sns.heatmap(genome_matrix)
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 537                           yticklabels, mask)
#     538
# ...

# %%
genome_matrix1 = pd.read_csv('genome_matrix.csv',index_col=0) #либо надо было drop удалить столбец
# df_genome = df_genome.drop('Unnamed: 0', axis=1)
# либо genome_matrix.set_index('Unnamed: 0')
genome_matrix1
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(genome_matrix1)

# %%
g = sns.heatmap(genome_matrix1, cmap="viridis")# ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # вопрос

# %% [markdown]
# ##### Пришло время узнать, кто самый главный рак какая роль в dota самая распространённая. Скачайте датасэт с данными о героях из игры dota 2 и посмотрите на распределение их возможных ролей в игре (колонка roles). Постройте гистограмму, отражающую скольким героям сколько ролей приписывается (по мнению Valve, конечно) и напишите какое число ролей у большинства героев.
# https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv
# Это задание можно выполнить многими путями, и рисовать гистограмму вообще говоря для этого не нужно.
#
# Данные взяты отсюда, на этом же сайте можно найти больше разнообразных данных по dota 2

# %%
dota_hero_stats=pd.read_csv('dota_hero_stats.csv',index_col=0)

# %%
dota_hero_stats
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
dota_hero_stats.roles.str.split(',')
# Out:
# 0                       [['Carry',  'Escape',  'Nuker']]
# 1      [['Initiator',  'Durable',  'Disabler',  'Jung...
# 2       [['Support',  'Disabler',  'Nuker',  'Durable']]
# 3      [['Carry',  'Disabler',  'Jungler',  'Nuker', ...
# 4       [['Support',  'Disabler',  'Nuker',  'Jungler']]
#                              ...
# 112    [['Carry',  'Escape',  'Disabler',  'Initiator']]
# 113      [['Support',  'Nuker',  'Disabler',  'Escape']]
# 114    [['Carry',  'Nuker',  'Disabler',  'Durable', ...
# 115      [['Support',  'Nuker',  'Disabler',  'Escape']]
# 116    [['Carry',  'Initiator',  'Disabler',  'Durabl...
# Name: roles, Length: 117, dtype: object

# %%
dota_hero_stats.roles.str.split(',').max()
# Out:
# ["['Support'", " 'Pusher'", " 'Disabler'", " 'Nuker'", " 'Initiator']"]

# %%
dota_hero_stats.roles.str.split(',').describe()
# Out:
# count                                                 117
# unique                                                100
# top       [['Support',  'Nuker',  'Disabler',  'Escape']]
# freq                                                    3
# Name: roles, dtype: object

# %%
dota_hero_stats.roles.str.split(',').str.len()
# Out:
# 0      3
# 1      4
# 2      4
# 3      5
# 4      4
#       ..
# 112    4
# 113    4
# 114    6
# 115    4
# 116    4
# Name: roles, Length: 117, dtype: int64

# %%
dota_hero_stats.roles[dota_hero_stats.roles.str.split(',').str.len() > 5].to_list()
# Out:
# ["['Initiator', 'Disabler', 'Support', 'Nuker', 'Escape', 'Jungler']",
#  "['Carry', 'Nuker', 'Pusher', 'Initiator', 'Durable', 'Disabler']",
#  "['Carry', 'Support', 'Disabler', 'Initiator', 'Durable', 'Nuker']",
#  "['Carry', 'Pusher', 'Durable', 'Disabler', 'Initiator', 'Nuker']",
#  "['Carry', 'Support', 'Durable', 'Disabler', 'Initiator', 'Nuker']",
#  "['Carry', 'Escape', 'Nuker', 'Disabler', 'Initiator', 'Pusher']",
#  "['Carry', 'Support', 'Pusher', 'Disabler', 'Initiator', 'Escape']",
#  "['Carry', 'Nuker', 'Disabler', 'Durable', 'Escape', 'Initiator']"]

# %%
dota_hero_stats.roles.str.split(',').str.len().hist()

# %%
dota_hero_stats.roles.str.split(",").str.len().mode()
# Out:
# 0    4
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dota_hero_stats.roles.str.split(',').apply(len).value_counts()
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: roles, dtype: int64

# %%
dota_hero_stats.roles.str.split(',').apply(len)
# Out:
# 0      3
# 1      4
# 2      4
# 3      5
# 4      4
#       ..
# 112    4
# 113    4
# 114    6
# 115    4
# 116    4
# Name: roles, Length: 117, dtype: int64

# %% [markdown]
# # вопрос

# %% [markdown]
# ###### Теперь перейдём к цветочкам. https://stepik.org/media/attachments/course/4852/iris.csv
# Магистрантка Адель решила изучить какие бывают ирисы. Помогите Адель узнать об ирисах больше - скачайте датасэт со значениями параметров ирисов, постройте их распределения и отметьте правильные утверждения, глядя на график.
#
# Распределение должно быть по всем образцам, без разделения на вид.
# Чтобы построить на 1-ом графике распределения для каждого из параметров, можно воспользоваться петлёй
#
# for column in df:
#     # Draw distribution with that column
# Ссылки для изучения:
#
# kdeplot https://seaborn.pydata.org/generated/seaborn.kdeplot.html
#
# distplot https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
iris = pd.read_csv('iris.csv', index_col=0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for column in iris:
    ax =sns.kdeplot(data=iris[column],label=column)
plt.legend()

# %%
sns.kdeplot(data=iris)

# %%
for column in iris:
#     sns.kdeplot(data=iris[column])
    sns.distplot(iris[column],label=column)
plt.legend()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(iris)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('наибольший размах:', (iris.describe().loc['max'] - iris.describe().loc['min']).idxmax())
# Out:
# наибольший размах: petal length

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %% [markdown]
# # задание

# %% [markdown]
# ###### Рассмотрим длину лепестков (petal length)
# подробнее и воспользуемся для этого violin плотом. Нарисуйте распределение длины лепестков ирисов из предыдущего датасэта с помощью violin плота и выберите правильный (такой же) вариант среди предложенных
#
# Мануал по рисованию violin плотов https://seaborn.pydata.org/generated/seaborn.violinplot.html
#
# ![image.png](attachment:image.png)

# %%
sns.violinplot(iris['petal length'], orient='h')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.violinplot(y=iris['petal length'],color="purple")

# %%
sns.violinplot(data = iris['petal length'], orient = 'v')

# %%
sns.violinplot(iris['petal length'], orient = 'v')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.violinplot(data = iris['petal length'], orient = 'v', color = 'purple')

# %% [markdown]
# # задание

# %% [markdown]
# ##### Продолжаем изучение ирисов!
# Ещё один важный тип графиков - pairplot, отражающий зависимость пар переменных друг от друга, а также распределение каждой из переменных. Постройте его и посмотрите на scatter плоты для каждой из пар фичей. Какая из пар навскидку имеет наибольшую корреляцию?
#
# Также обратите внимание, что можно разделить на группы с помощью параметра hue.
#
# Ссылки для изучения:
#
# pairplot https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.heatmap(iris[iris.columns[0:4]].corr(), annot=True, square=True, cmap='coolwarm')

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000
