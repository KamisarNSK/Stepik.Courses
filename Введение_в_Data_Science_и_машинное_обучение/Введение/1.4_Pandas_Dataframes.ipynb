# %% [markdown]
# # 1.4 Pandas, Dataframes

# %% [markdown]
# ## Какие способы позволяют отобрать 7 первых строк датафрэйма df

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## А теперь простой вопрос на соответствие атрибутов и методов датафрэйма с их значением
#
# Здесь можно посмотреть описание атрибутов и методов
# https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#attributes-and-underlying-data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## А теперь используем эти методы на знаменитом титаническом датасэте! Загрузите датасэт, посмотрите на датафрэйм и ответьте на вопросы
# https://stepik.org/media/attachments/course/4852/titanic.csv
# Комментарий: в ответе необходимо указать количество колонок.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
patch_to_file = 'titanic.csv'

titanic = pd.read_csv(patch_to_file)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.dtypes.count()
# Out:
# 12

# %%
titanic.size
# Out:
# 10692

# %%
titanic.dtypes.describe()
# Out:
# count         12
# unique         3
# top       object
# freq           5
# dtype: object

# %%
titanic.dtypes.value_counts()
# Out:
# object     5
# int64      5
# float64    2
# dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.iloc[0:5, 3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
titanic.iloc[[1,3,5], [0,1,5,6,-1]]
# Out:
#    PassengerId  Survived   Age  SibSp Embarked
# 1            2         1  38.0      1        C
# 3            4         1  35.0      1        S
# 5            6         0   NaN      0        Q

# %%
mini_df = titanic.iloc[0:5]
mini_df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
mini_df.index = ['маня','вася','петя','сигузмунд','мойша']
mini_df
# Out:
#            PassengerId  Survived  Pclass  \
# маня                 1         0       3
# вася                 2         1       1
# петя                 3         1       3
# сигузмунд            4         1       1
# мойша                5         0       3
#
#                                                         Name     Sex   Age  \
# маня                                 Braund, Mr. Owen Harris    male  22.0
# вася       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# петя                                  Heikkinen, Miss. Laina  female  26.0
# сигузмунд       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# мойша                               Allen, Mr. William Henry    male  35.0
#
#            SibSp  Parch            Ticket     Fare Cabin Embarked
# маня           1      0         A/5 21171   7.2500   NaN        S
# вася           1      0          PC 17599  71.2833   C85        C
# ...

# %%
mini_df.loc[['маня','мойша']]
# Out:
#        PassengerId  Survived  Pclass                      Name   Sex   Age  \
# маня             1         0       3   Braund, Mr. Owen Harris  male  22.0
# мойша            5         0       3  Allen, Mr. William Henry  male  35.0
#
#        SibSp  Parch     Ticket  Fare Cabin Embarked
# маня       1      0  A/5 21171  7.25   NaN        S
# мойша      0      0     373450  8.05   NaN        S

# %%
mini_df.loc[['маня','мойша'],['Sex','Age']]
# Out:
#         Sex   Age
# маня   male  22.0
# мойша  male  35.0

# %%
mini_df.iloc[:, 0]
# Out:
# маня         1
# вася         2
# петя         3
# сигузмунд    4
# мойша        5
# Name: PassengerId, dtype: int64

# %%
type(mini_df.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1,2,3], index=['вася','петя','сигузмунд'])
# Out:
# вася         1
# петя         2
# сигузмунд    3
# dtype: int64

# %%
my_series1 = pd.Series([1,2,3], index=['вася','петя','сигузмунд'])
my_series2 = pd.Series([4,5,6], index=['вася','петя','сигузмунд'])

# %%
pd.DataFrame({'col_name_1':my_series1, 'col_name_2':my_series2})
# Out:
#            col_name_1  col_name_2
# вася                1           4
# петя                2           5
# сигузмунд           3           6

# %%
mini_df
# Out:
#            PassengerId  Survived  Pclass  \
# маня                 1         0       3
# вася                 2         1       1
# петя                 3         1       3
# сигузмунд            4         1       1
# мойша                5         0       3
#
#                                                         Name     Sex   Age  \
# маня                                 Braund, Mr. Owen Harris    male  22.0
# вася       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# петя                                  Heikkinen, Miss. Laina  female  26.0
# сигузмунд       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# мойша                               Allen, Mr. William Henry    male  35.0
#
#            SibSp  Parch            Ticket     Fare Cabin Embarked
# маня           1      0         A/5 21171   7.2500   NaN        S
# вася           1      0          PC 17599  71.2833   C85        C
# ...

# %%
mini_df['Name']
# Out:
# маня                                   Braund, Mr. Owen Harris
# вася         Cumings, Mrs. John Bradley (Florence Briggs Th...
# петя                                    Heikkinen, Miss. Laina
# сигузмунд         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# мойша                                 Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
mini_df[['Name']]
# Out:
#                                                         Name
# маня                                 Braund, Mr. Owen Harris
# вася       Cumings, Mrs. John Bradley (Florence Briggs Th...
# петя                                  Heikkinen, Miss. Laina
# сигузмунд       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# мойша                               Allen, Mr. William Henry
