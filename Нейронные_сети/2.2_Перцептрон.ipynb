# %% [markdown]
# # 2.2 Перцептрон

# %% [markdown]
# # вопрос

# %% [markdown]
# # Итак, перцептрон — это оператор вида
#
# ![image.png](attachment:image.png)
#
# Если представить перцептрон в том же виде, что и любой другой стандартный искусственный нейрон (то есть выделить сумматорную и активационную функцию), то какие утверждения будут для него верны?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### это активационная функция

# %% [markdown]
#  $$f(t) = \left\lbrace\begin{array}{t} 1,&\text{ если } t > 0, \\ 0 &\text{иначе}\end{array}\right.$$

# %% [markdown]
# # вопрос

# %% [markdown]
# ### Отметьте наборы весов и входов (комбинаций входных факторов), при которых вы решите поехать к бабушке.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ВОПРОС

# %% [markdown]
# ### Продолжая историю с бабушкой, соотнесите векторы весов и описания их обладателей.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ВОПРОС
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
